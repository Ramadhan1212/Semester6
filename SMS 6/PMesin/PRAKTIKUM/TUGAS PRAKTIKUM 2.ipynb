# %%
#iqbal putra ramadhan
#teori D
#1197050054

import pandas as pd
import matplotlib.pyplot as plt

# %%
path = "covid19.csv"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#   Province/State Country/Region      Lat     Long     Date  Confirmed  Deaths  \
# 0            NaN    Afghanistan  33.0000  65.0000  1/22/20          0       0
# 1            NaN        Albania  41.1533  20.1683  1/22/20          0       0
# 2            NaN        Algeria  28.0339   1.6596  1/22/20          0       0
# 3            NaN        Andorra  42.5063   1.5218  1/22/20          0       0
# 4            NaN         Angola -11.2027  17.8739  1/22/20          0       0
#
#    Recovered
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
kasus1 = df[df['Country/Region'] == 'Indonesia']
kasus1
# Out:
#       Province/State Country/Region     Lat      Long     Date  Confirmed  \
# 132              NaN      Indonesia -0.7893  113.9213  1/22/20          0
# 397              NaN      Indonesia -0.7893  113.9213  1/23/20          0
# 662              NaN      Indonesia -0.7893  113.9213  1/24/20          0
# 927              NaN      Indonesia -0.7893  113.9213  1/25/20          0
# 1192             NaN      Indonesia -0.7893  113.9213  1/26/20          0
# ...              ...            ...     ...       ...      ...        ...
# 30872            NaN      Indonesia -0.7893  113.9213  5/17/20      17514
# 31137            NaN      Indonesia -0.7893  113.9213  5/18/20      18010
# 31402            NaN      Indonesia -0.7893  113.9213  5/19/20      18496
# 31667            NaN      Indonesia -0.7893  113.9213  5/20/20      19189
# 31932            NaN      Indonesia -0.7893  113.9213  5/21/20      20162
#
#        Deaths  Recovered
# 132         0          0
# 397         0          0
# ...

# %%
kasus2 = df[df['Country/Region'] == 'Japan']
kasus2
# Out:
#       Province/State Country/Region   Lat   Long     Date  Confirmed  Deaths  \
# 139              NaN          Japan  36.0  138.0  1/22/20          2       0
# 404              NaN          Japan  36.0  138.0  1/23/20          2       0
# 669              NaN          Japan  36.0  138.0  1/24/20          2       0
# 934              NaN          Japan  36.0  138.0  1/25/20          2       0
# 1199             NaN          Japan  36.0  138.0  1/26/20          4       0
# ...              ...            ...   ...    ...      ...        ...     ...
# 30879            NaN          Japan  36.0  138.0  5/17/20      16285     744
# 31144            NaN          Japan  36.0  138.0  5/18/20      16305     749
# 31409            NaN          Japan  36.0  138.0  5/19/20      16367     768
# 31674            NaN          Japan  36.0  138.0  5/20/20      16367     768
# 31939            NaN          Japan  36.0  138.0  5/21/20      16424     777
#
#        Recovered
# 139            0
# ...

# %%
kasus_ind = kasus1[kasus1['Confirmed'] > 0]
kasus_ind
# Out:
#       Province/State Country/Region     Lat      Long     Date  Confirmed  \
# 10732            NaN      Indonesia -0.7893  113.9213   3/2/20          2
# 10997            NaN      Indonesia -0.7893  113.9213   3/3/20          2
# 11262            NaN      Indonesia -0.7893  113.9213   3/4/20          2
# 11527            NaN      Indonesia -0.7893  113.9213   3/5/20          2
# 11792            NaN      Indonesia -0.7893  113.9213   3/6/20          4
# ...              ...            ...     ...       ...      ...        ...
# 30872            NaN      Indonesia -0.7893  113.9213  5/17/20      17514
# 31137            NaN      Indonesia -0.7893  113.9213  5/18/20      18010
# 31402            NaN      Indonesia -0.7893  113.9213  5/19/20      18496
# 31667            NaN      Indonesia -0.7893  113.9213  5/20/20      19189
# 31932            NaN      Indonesia -0.7893  113.9213  5/21/20      20162
#
#        Deaths  Recovered
# 10732       0          0
# 10997       0          0
# ...

# %%
kasus_jpn = kasus2[kasus2['Confirmed'] > 0]
kasus_jpn
# Out:
#       Province/State Country/Region   Lat   Long     Date  Confirmed  Deaths  \
# 139              NaN          Japan  36.0  138.0  1/22/20          2       0
# 404              NaN          Japan  36.0  138.0  1/23/20          2       0
# 669              NaN          Japan  36.0  138.0  1/24/20          2       0
# 934              NaN          Japan  36.0  138.0  1/25/20          2       0
# 1199             NaN          Japan  36.0  138.0  1/26/20          4       0
# ...              ...            ...   ...    ...      ...        ...     ...
# 30879            NaN          Japan  36.0  138.0  5/17/20      16285     744
# 31144            NaN          Japan  36.0  138.0  5/18/20      16305     749
# 31409            NaN          Japan  36.0  138.0  5/19/20      16367     768
# 31674            NaN          Japan  36.0  138.0  5/20/20      16367     768
# 31939            NaN          Japan  36.0  138.0  5/21/20      16424     777
#
#        Recovered
# 139            0
# ...

# %%
#Menambahkan date base untuk indonesia dan japan

kasus_ind['Date'] = pd.to_datetime(kasus_ind['Date'])
kasus_jpn['Date'] = pd.to_datetime(kasus_jpn['Date'])
kasus_ind
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_920\3830740849.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kasus_ind['Date'] = pd.to_datetime(kasus_ind['Date'])
#       Province/State Country/Region     Lat      Long       Date  Confirmed  \
# 10732            NaN      Indonesia -0.7893  113.9213 2020-03-02          2
# 10997            NaN      Indonesia -0.7893  113.9213 2020-03-03          2
# 11262            NaN      Indonesia -0.7893  113.9213 2020-03-04          2
# 11527            NaN      Indonesia -0.7893  113.9213 2020-03-05          2
# 11792            NaN      Indonesia -0.7893  113.9213 2020-03-06          4
# ...              ...            ...     ...       ...        ...        ...
# ...

# %%
kasus_ind['BaseDate'] = pd.to_datetime('2020-03-02')
kasus_ind.head()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_920\2618738624.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kasus_ind['BaseDate'] = pd.to_datetime('2020-03-02')
#       Province/State Country/Region     Lat      Long       Date  Confirmed  \
# 10732            NaN      Indonesia -0.7893  113.9213 2020-03-02          2
# 10997            NaN      Indonesia -0.7893  113.9213 2020-03-03          2
# 11262            NaN      Indonesia -0.7893  113.9213 2020-03-04          2
# 11527            NaN      Indonesia -0.7893  113.9213 2020-03-05          2
# 11792            NaN      Indonesia -0.7893  113.9213 2020-03-06          4
#
#        Deaths  Recovered   BaseDate
# 10732       0          0 2020-03-02
# ...

# %%
kasus_jpn['BaseDate'] = pd.to_datetime('2020-01-22')
kasus_jpn.head()
# Out:
#      Province/State Country/Region   Lat   Long       Date  Confirmed  Deaths  \
# 139             NaN          Japan  36.0  138.0 2020-01-22          2       0
# 404             NaN          Japan  36.0  138.0 2020-01-23          2       0
# 669             NaN          Japan  36.0  138.0 2020-01-24          2       0
# 934             NaN          Japan  36.0  138.0 2020-01-25          2       0
# 1199            NaN          Japan  36.0  138.0 2020-01-26          4       0
#
#       Recovered   BaseDate
# 139           0 2020-01-22
# 404           0 2020-01-22
# 669           0 2020-01-22
# 934           0 2020-01-22
# 1199          1 2020-01-22

# %%
kasus_jpn
# Out:
#       Province/State Country/Region   Lat   Long       Date  Confirmed  \
# 139              NaN          Japan  36.0  138.0 2020-01-22          2
# 404              NaN          Japan  36.0  138.0 2020-01-23          2
# 669              NaN          Japan  36.0  138.0 2020-01-24          2
# 934              NaN          Japan  36.0  138.0 2020-01-25          2
# 1199             NaN          Japan  36.0  138.0 2020-01-26          4
# ...              ...            ...   ...    ...        ...        ...
# 30879            NaN          Japan  36.0  138.0 2020-05-17      16285
# 31144            NaN          Japan  36.0  138.0 2020-05-18      16305
# 31409            NaN          Japan  36.0  138.0 2020-05-19      16367
# 31674            NaN          Japan  36.0  138.0 2020-05-20      16367
# 31939            NaN          Japan  36.0  138.0 2020-05-21      16424
#
#        Deaths  Recovered   BaseDate
# 139         0          0 2020-01-22
# 404         0          0 2020-01-22
# ...

# %%
#selisih tanggal 

kasus_ind['HariKe'] = (kasus_ind['Date'] - kasus_ind['BaseDate'])
kasus_jpn['HariKe'] = (kasus_jpn['Date'] - kasus_jpn['BaseDate'])
kasus_ind
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_920\1457075626.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kasus_ind['HariKe'] = (kasus_ind['Date'] - kasus_ind['BaseDate'])
#       Province/State Country/Region     Lat      Long       Date  Confirmed  \
# 10732            NaN      Indonesia -0.7893  113.9213 2020-03-02          2
# 10997            NaN      Indonesia -0.7893  113.9213 2020-03-03          2
# 11262            NaN      Indonesia -0.7893  113.9213 2020-03-04          2
# 11527            NaN      Indonesia -0.7893  113.9213 2020-03-05          2
# 11792            NaN      Indonesia -0.7893  113.9213 2020-03-06          4
# ...              ...            ...     ...       ...        ...        ...
# ...

# %%
kasus_ind.HariKe = kasus_ind.HariKe/pd.Timedelta(1,  unit='d')
kasus_ind.head()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_920\1871455948.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kasus_ind.HariKe = kasus_ind.HariKe/pd.Timedelta(1,  unit='d')
#       Province/State Country/Region     Lat      Long       Date  Confirmed  \
# 10732            NaN      Indonesia -0.7893  113.9213 2020-03-02          2
# 10997            NaN      Indonesia -0.7893  113.9213 2020-03-03          2
# 11262            NaN      Indonesia -0.7893  113.9213 2020-03-04          2
# 11527            NaN      Indonesia -0.7893  113.9213 2020-03-05          2
# 11792            NaN      Indonesia -0.7893  113.9213 2020-03-06          4
#
#        Deaths  Recovered   BaseDate  HariKe
# 10732       0          0 2020-03-02     0.0
# ...

# %%
kasus_jpn
# Out:
#       Province/State Country/Region   Lat   Long       Date  Confirmed  \
# 139              NaN          Japan  36.0  138.0 2020-01-22          2
# 404              NaN          Japan  36.0  138.0 2020-01-23          2
# 669              NaN          Japan  36.0  138.0 2020-01-24          2
# 934              NaN          Japan  36.0  138.0 2020-01-25          2
# 1199             NaN          Japan  36.0  138.0 2020-01-26          4
# ...              ...            ...   ...    ...        ...        ...
# 30879            NaN          Japan  36.0  138.0 2020-05-17      16285
# 31144            NaN          Japan  36.0  138.0 2020-05-18      16305
# 31409            NaN          Japan  36.0  138.0 2020-05-19      16367
# 31674            NaN          Japan  36.0  138.0 2020-05-20      16367
# 31939            NaN          Japan  36.0  138.0 2020-05-21      16424
#
#        Deaths  Recovered   BaseDate   HariKe
# 139         0          0 2020-01-22   0 days
# ...

# %%
kasus_jpn.HariKe = kasus_jpn.HariKe/pd.Timedelta(1,  unit='d')
kasus_jpn.head()
# Out:
#      Province/State Country/Region   Lat   Long       Date  Confirmed  Deaths  \
# 139             NaN          Japan  36.0  138.0 2020-01-22          2       0
# 404             NaN          Japan  36.0  138.0 2020-01-23          2       0
# 669             NaN          Japan  36.0  138.0 2020-01-24          2       0
# 934             NaN          Japan  36.0  138.0 2020-01-25          2       0
# 1199            NaN          Japan  36.0  138.0 2020-01-26          4       0
#
#       Recovered   BaseDate  HariKe
# 139           0 2020-01-22     0.0
# 404           0 2020-01-22     1.0
# 669           0 2020-01-22     2.0
# 934           0 2020-01-22     3.0
# 1199          1 2020-01-22     4.0

# %%
plt.plot(kasus_ind.HariKe, kasus_ind.Confirmed)
plt.plot(kasus_jpn.HariKe, kasus_jpn.Confirmed)
plt.xlabel('Hari ke-')
plt.ylabel('Jumlah kasus')
plt.title('SELISIH ANGKA COVID JEPANG DAN INDONESIA')
plt.legend(['Indonesia', 'Jepang'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
